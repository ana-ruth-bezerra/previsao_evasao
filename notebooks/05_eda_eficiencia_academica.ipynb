# %% [markdown]
# ### **EDA - Eficiência Acadêmica**

# %%
# Importar bibliotecas necessárias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Carregar o DataFrame tratado para análise exploratória
df_eda = pd.read_parquet('../data/processed/microdados_eficiencia_academica_tratados.parquet')

# %%
df_eda.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   carga_horaria           60 non-null     int64
#  1   codigo_ciclo_matricula  60 non-null     str
#  2   fator_esforco_curso     60 non-null     float64
#  3   modalidade_ensino       60 non-null     str
#  4   nome_curso              60 non-null     str
#  5   tipo_curso              60 non-null     str
#  6   unidade_ensino          60 non-null     str
# dtypes: float64(1), int64(1), str(5)
# memory usage: 7.9 KB

# %%
df_eda.head(10)
# Out:
#    carga_horaria codigo_ciclo_matricula  fator_esforco_curso  \
# 0           3630                2146517                1.108
# 1           3630                2168415                1.108
# 2           3990                2171089                1.078
# 3           3020                2187094                1.000
# 4           4140                2457272                1.025
# 5           3890                2457273                1.108
# 6           3720                2447665                1.108
# 7           3720                2447667                1.078
# 8           3720                2447671                1.111
# 9           3290                2485508                1.000
#
#       modalidade_ensino            nome_curso    tipo_curso  \
# 0   Educação Presencial   Engenharia Elétrica   Bacharelado
# 1   Educação Presencial   Engenharia Elétrica   Bacharelado
# 2   Educação Presencial   Engenharia Mecânica   Bacharelado
# 3  Educação a Distância            Computação  Licenciatura
# 4   Educação Presencial  Engenharia Ambiental   Bacharelado
# 5   Educação Presencial   Engenharia Elétrica   Bacharelado
# 6   Educação Presencial   Engenharia Elétrica   Bacharelado
# 7   Educação Presencial   Engenharia Mecânica   Bacharelado
# 8   Educação Presencial    Engenharia Química   Bacharelado
# 9   Educação Presencial            Matemática  Licenciatura
#
#                 unidade_ensino
# 0          Campus Paulo Afonso
# 1          Campus Paulo Afonso
# 2          Campus Simões Filho
# 3           Campus Santo Amaro
# 4  Campus Vitória da Conquista
# 5  Campus Vitória da Conquista
# 6              Campus Salvador
# 7              Campus Salvador
# 8              Campus Salvador
# 9         Campus Valença Tento

# %%
# Medidas estatísticas dos atributos numéricos
df_eda.describe()
# Out:
#        carga_horaria  fator_esforco_curso
# count      60.000000            60.000000
# mean     3231.666667             1.044583
# std       554.275880             0.046496
# min      2010.000000             1.000000
# 25%      2950.000000             1.000000
# 50%      3275.000000             1.030000
# 75%      3720.000000             1.085000
# max      4140.000000             1.175000

# %%
df_numerico = df_eda.select_dtypes(include='number')

# %%
# Gráfico de dispersão
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df_eda, x='carga_horaria', y='fator_esforco_curso')
plt.title('Carga Horária vs Fator de Esforço do Curso')
plt.xlabel('Carga Horária')
plt.ylabel('Fator de Esforço do Curso')
plt.grid(True)
plt.show()

# Boxplots
plt.figure(figsize=(8, 6))
sns.boxplot(data=df_eda, y='carga_horaria')
plt.show()

plt.figure(figsize=(8, 6))
sns.boxplot(data=df_eda, y='fator_esforco_curso')
plt.show()

# Correlações
plt.figure(figsize=(8, 6))
sns.heatmap(df_numerico.corr(method='pearson'), annot=True)
plt.title('Correlação (Pearson)')
plt.show()
